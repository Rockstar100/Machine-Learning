# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import linear_model
df=pd.read_csv('Tax.csv')
df
# Out:
#    Year       Tax
# 0  2018  10616.96
# 1  2019  12008.95
# 2  2020  10345.78
# 3  2021  10638.21
# 4  2022  15288.79
# 5  2023  17163.65

# %%
plt.xlabel('Distance')
plt.ylabel('Cost')
plt.scatter(df.Year,df.Tax,color="blue")

# %%
new_df=df.drop('Tax',axis="columns")
new_df
# Out:
#    Year
# 0  2018
# 1  2019
# 2  2020
# 3  2021
# 4  2022
# 5  2023

# %%
model=linear_model.LinearRegression()
model.fit(new_df,df.Tax)
# Out:
# LinearRegression()

# %%
model.predict([[2070]])
# Out:
# c:\Users\boyro\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([73300.97952381])

# %%
model.coef_
# Out:
# array([1224.72571429])

# %%
model.intercept_
# Out:
# -2461881.2490476193

# %%
1224.72571429*2070-2461881.2490476193
# Out:
# 73300.97953268094

# %%
area_df=pd.read_excel('predict.xlsx')
area_df
# Out:
#    Year
# 0  2024
# 1  2034
# 2  2090
# 3  3014
# 4  2060
# 5  2031
# 6  2065
# 7  2070

# %%
p=model.predict(area_df)

# %%
area_df['Prediction']=p
area_df
# Out:
#    Year    Prediction
# 0  2024  1.696360e+04
# 1  2034  2.921085e+04
# 2  2090  9.779549e+04
# 3  3014  1.229442e+06
# 4  2060  6.105372e+04
# 5  2031  2.553668e+04
# 6  2065  6.717735e+04
# 7  2070  7.330098e+04

# %%
area_df.to_csv("prediction.csv")
